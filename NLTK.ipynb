# %%
import nltk

# %%
text="Today is a great day. It is even better than yesterday." + \
     " And yesterday was the best day ever."

# %%
# split sentence
nltk.sent_tokenize(text)
# Out:
# ['Today is a great day.',
#  'It is even better than yesterday.',
#  'And yesterday was the best day ever.']

# %%
# word tokenize
nltk.word_tokenize(text)
# Out:
# ['Today',
#  'is',
#  'a',
#  'great',
#  'day',
#  '.',
#  'It',
#  'is',
#  'even',
#  'better',
#  'than',
#  'yesterday',
#  '.',
#  'And',
#  'yesterday',
#  'was',
#  'the',
#  'best',
#  'day',
#  'ever',
#  '.']

# %%
# 字根詞形還原(Stemming)
# his -> hi, daily-> daili
text = 'My system keeps crashing his crashed yesterday, ours crashes daily'
ps = nltk.porter.PorterStemmer()
' '.join([ps.stem(word) for word in text.split()])
# Out:
# 'my system keep crash hi crash yesterday, our crash daili'

# %%
# 依字典規則的詞形還原(Lemmatization)
text = 'My system keeps crashing his crashed yesterday, ours crashes daily'
lem = nltk.WordNetLemmatizer()
' '.join([lem.lemmatize(word) for word in text.split()])
# Out:
# 'My system keep crashing his crashed yesterday, ours crash daily'

# %%
# remove stopwords
# 標點符號(Punctuation)
import string
print('標點符號:', string.punctuation)
# Out:
# 標點符號: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
nltk.corpus.stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
# chinese
nltk.corpus.stopwords.words('chinese')
# Out:
# ['一',
#  '一下',
#  '一些',
#  '一切',
#  '一则',
#  '一天',
#  '一定',
#  '一方面',
#  '一旦',
#  '一时',
#  '一来',
#  '一样',
#  '一次',
#  '一片',
#  '一直',
#  '一致',
#  '一般',
#  '一起',
#  '一边',
#  '一面',
#  '万一',
#  '上下',
#  '上升',
#  '上去',
#  '上来',
#  '上述',
#  '上面',
#  '下列',
#  '下去',
#  '下来',
#  '下面',
#  '不一',
#  '不久',
#  '不仅',
#  '不会',
#  '不但',
#  '不光',
#  '不单',
#  '不变',
#  '不只',
#  '不可',
#  '不同',
#  '不够',
#  '不如',
#  '不得',
#  '不怕',
#  '不惟',
#  '不成',
#  '不拘',
#  '不敢',
#  '不断',
#  '不是',
#  '不比',
#  '不然',
#  '不特',
#  '不独',
#  '不管',
#  '不能',
#  '不要',
#  '不论',
#  '不足',
#  '不过',
#  '不问',
#  '与',
#  '与其',
#  '与否',
#  '与此同时',
#  '专门',
#  '且',
#  '两者',
#  '严格',
#  '严重',
#  '个',
#  '个人',
#  '个别',
#  '中小',
#  '中间',
#  '丰富',
#  '临',
#  '为',
#  '为主',
#  '为了',
#  '为什么',
#  '为什麽',
#  '为何',
#  '为着',
#  '主张',
#  '主要',
#  '举行',
#  '乃',
#  '乃至',
#  '么',
#  '之',
#  '之一',
#  '之前',
#  '之后',
#  '之後',
#  '之所以',
#  '之类',
#  '乌乎',
#  '乎',
#  '乘',
#  '也',
#  '也好',
#  '也是',
#  '也罢',
#  '了',
#  '了解',
#  '争取',
#  '于',
#  '于是',
# ...

# %%
nltk.corpus.stopwords.words?
# Out:
# Signature: nltk.corpus.stopwords.words(fileids=None, ignore_lines_startswith='\n')
# Docstring: <no docstring>
# File:      c:\users\a4022\anaconda3\lib\site-packages\nltk\corpus\reader\wordlist.py
# Type:      method

# %% [markdown]
# ## stopwords

# %%
# set stop words included punctuation
eng_stopword_list = set(nltk.corpus.stopwords.words('english') 
                    + list(string.punctuation))
print("stop words:", eng_stopword_list)
# Out:
# stop words: {'all', '[', 'this', "wasn't", 'only', 'here', 'while', 'their', 'them', 'have', ';', 'is', 'an', 'hadn', 'haven', 'for', "weren't", 'ain', 'the', 'will', "couldn't", '&', "you've", 'those', 'both', '{', 'after', '/', "you'll", 'does', 'so', "she's", 'her', 'shouldn', 'd', 'in', 'once', '%', 'some', "needn't", '-', 'herself', 'they', 'y', 'myself', 'weren', 'over', 'mustn', 'ours', 'between', 'of', '"', 'more', '@', 'that', 'our', 'you', 'below', 'aren', "that'll", 'your', 'needn', "wouldn't", 'won', 'what', 'same', '!', 'again', 'm', 'up', 'out', ']', 'where', 've', 'off', 'do', 'there', 'he', 'me', 'be', '?', 'at', 'other', 'to', 'was', "'", "haven't", 'who', '}', 'i', 'then', 'as', 'any', "aren't", 'own', 'it', 'very', '+', '_', 'but', 'under', "shan't", 'wasn', "you'd", 'until', 'couldn', '$', 'which', "won't", 'o', 'from', 'further', '^', 'had', 'doesn', '`', 'with', 't', '#', 'wouldn', 'his', 'ma', ')', 'and', 'its', 'few', '.', '*', ':', 'him', 'on', '\\', 'during'
# ...

# %%
# Test article paragraph
eng_text="Today is a great day. It is even better than yesterday." + \
     " And yesterday was the best day ever."

# %%
# Removing Stopwords 1
def remove_stopwords(test):
    return ' '.join([word for word in test.split() if word not in eng_stopword_list])

filtered_text = remove_stopwords(eng_text)
print("filtered text 1:", filtered_text)
# Out:
# filtered text 1: Today great day. It even better yesterday. And yesterday best day ever.

# %%
# Removing Stopwords 2
def remove_stopwords(text, is_lower_case=False):
    if is_lower_case:
        text = text.lower()
    tokens = nltk.word_tokenize(text)
    print("tokens:", tokens)
    tokens = [token.strip() for token in tokens] # remove blank
    print("striped tokens:", tokens)
    filtered_tokens = [token for token in tokens if token not in eng_stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text, filtered_tokens

filtered_text, filtered_tokens = remove_stopwords(eng_text)
print()
print("filtered text 2:", filtered_text)
print("filtered tokens:", filtered_tokens)
# Out:
# tokens: ['Today', 'is', 'a', 'great', 'day', '.', 'It', 'is', 'even', 'better', 'than', 'yesterday', '.', 'And', 'yesterday', 'was', 'the', 'best', 'day', 'ever', '.']
# striped tokens: ['Today', 'is', 'a', 'great', 'day', '.', 'It', 'is', 'even', 'better', 'than', 'yesterday', '.', 'And', 'yesterday', 'was', 'the', 'best', 'day', 'ever', '.']
#
# filtered text 2: Today great day It even better yesterday And yesterday best day ever
# filtered tokens: ['Today', 'great', 'day', 'It', 'even', 'better', 'yesterday', 'And', 'yesterday', 'best', 'day', 'ever']

# %%
# Chinese test article paragraph
## reference: https://tech.udn.com/tech/story/123454/7519750
cn_text="史丹佛大學人本人工智慧 學院 (Stanford University Human-Centered Artificial Intelligence,Stanford HAI)" + \
     "稍早公布10款被大量採用的大型自然語言模型透明度指標，其中獲得最高分的是Meta旗下Llama 2，而排名最低的則是亞馬遜旗下Titan" + \
     "Text，至於OpenAI 的GPT-4則在排名第四，Google的PaLM 2則位居第五，在Stability.ai排名之後。不過，報告中也指出即便Llama 2" + \
     "在10款大型自然語言模型中的透明度排名第一，但實際上的透明度僅有54%，而Google的PaLM 2也僅有40%透明度，作為商用的亞馬遜Titan" + \
     "Text透明度更僅有12%。此指標報告的透明度計算方式，包含業者是否對外公布模型運作模式、規模及架構等，另外也包是否提供相關監控機制" +\
     "及補救調整方式，而透明度高低更意味使用者能信賴大型自然語言模型的程度。而從負責使指標報告製作的史丹佛大學人本人工智慧學院" + \
     "基礎模型研究中心看法認為，當前列入計算的大型自然語言模型實際上都無法完全信賴，並不建議企業或政府機構運用此類模型打造服務。" + \
     "史丹佛大學人本人工智慧學院總計制定100項用於評估大型自然語言模型透明度的指標，其中約三分之一用於評估模型如何被建立、" + \
     "訓練使用資料、建立模型時花費人力等，而其他三分之一則包含模型實際運作表現、可信度、風險程度，以及改善方式，剩餘三分之一" + \
     "則包含提供模型的業者採取政策、業者是否針對受影響情況提供協助等。"

# %%
# set stop words included punctuation
Chinese_punc = "！？｡。＂＃＄％＆＇（）＊＋，－／：；＜＝＞＠［＼］＾＿｀｛｜｝～｟｠｢｣､、〃》「」『』【】〔〕〖〗〘〙〚〛〜〝〞〟〰〾〿–—‘’‛“”„‟…‧﹏."
cn_stopword_list = set(nltk.corpus.stopwords.words('chinese') 
                    + list(string.punctuation) + list(Chinese_punc)
                    + list(string.punctuation))
print("stop words:", cn_stopword_list)
# Out:
# stop words: {'〝', '你', '存在', '吗', '共同', '用', '相对', '今後', '相等', '因为', '尔后', '相似', '之一', '一次', '后来', '可', '第', '』', '如此', '首先', '/', '直到', '上下', '前面', '有力', '最好', '有着', '一片', '大多数', '兮', '加之', '那么样', '何', '好象', '有的', '吧', '"', '离', '倘若', '战斗', '可以', '看见', '一定', '向着', '人家', '往往', '之', '毫不', '立即', '与否', '至', '来', '而且', '较', '呸', '了', '完全', '哪些', '遇到', '与其', '对应', '看到', '们', '虽则', '先生', '那儿', '这样', '不单', '尽管', '万一', '则', '几时', '取得', '一样', '意思', '运用', '部分', '省得', '相同', '特点', '原来', '吧哒', '加以', '嗬', '当着', '过去', '?', '同一', '朝着', '替', '哪怕', '两者', '今天', '例如', '需要', '就', '进而', '〙', '这时', '〘', '总的来说', '沿', '有效', '做到', '这么点儿', '其二', '此外', '看来', '+', '故', '〾', '还是', '宣布', '一面', '总之', '否则', '、', '自从', '这么些', '正常', '＾', '它们', '特殊', '应当', '俺们', '甚么', '以免', '嘛', '这种', '何况', '〖', '岂但', '较之', '实际', '某些', '只要', '不变', ')', '仍然', '［', '掌握', '咦', '以致', '继续', '深入', '﹏', '这会儿', '大大', '依', '前后', '哗', '的', '该', '形成', '认为', '哦', '嘻', '反过来', '曾经', '这些', '论', '经', '这麽', '可是', '上述', '咋', '各种', '由于', '为', '呗', '从事', 
# ...

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# nltk無法處理中文斷詞
# Removing Stopwords 2
def remove_stopwords(text, is_lower_case=False):
    if is_lower_case:
        text = text.lower()
    tokens = nltk.word_tokenize(text)
    print("tokens:", tokens)
    tokens = [token.strip() for token in tokens] # remove blank
    print("striped tokens:", tokens)
    filtered_tokens = [token for token in tokens if token not in cn_stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text, filtered_tokens

filtered_text, filtered_tokens = remove_stopwords(cn_text)
print()
print("filtered text 2:", filtered_text)
print("filtered tokens:", filtered_tokens)
# Out:
# tokens: ['史丹佛大學人本人工智慧', '學院', '(', 'Stanford', 'University', 'Human-Centered', 'Artificial', 'Intelligence', ',', 'Stanford', 'HAI', ')', '稍早公布10款被大量採用的大型自然語言模型透明度指標，其中獲得最高分的是Meta旗下Llama', '2，而排名最低的則是亞馬遜旗下TitanText，至於OpenAI', '的GPT-4則在排名第四，Google的PaLM', '2則位居第五，在Stability.ai排名之後。不過，報告中也指出即便Llama', '2在10款大型自然語言模型中的透明度排名第一，但實際上的透明度僅有54', '%', '，而Google的PaLM', '2也僅有40', '%', '透明度，作為商用的亞馬遜TitanText透明度更僅有12', '%', '。此指標報告的透明度計算方式，包含業者是否對外公布模型運作模式、規模及架構等，另外也包是否提供相關監控機制及補救調整方式，而透明度高低更意味使用者能信賴大型自然語言模型的程度。而從負責使指標報告製作的史丹佛大學人本人工智慧學院基礎模型研究中心看法認為，當前列入計算的大型自然語言模型實際上都無法完全信賴，並不建議企業或政府機構運用此類模型打造服務。史丹佛大學人本人工智慧學院總計制定100項用於評估大型自然語言模型透明度的指標，其中約三分之一用於評估模型如何被建立、訓練使用資料、建立模型時花費人力等，而其他三分之一則包含模型實際運作表現、可信度、風險程度，以及改善方式，剩餘三分之一則包含提供模型的業者採取政策、業者是否針對受影響情況提供協助等。']
# ...

# %% [markdown]
# ## BOW test

# %%
# set stop words included punctuation
eng_stopword_list = set(nltk.corpus.stopwords.words('english') 
                    + list(string.punctuation))
print("stop words:", eng_stopword_list)
# Out:
# stop words: {'all', '[', 'this', "wasn't", 'only', 'here', 'while', 'their', 'them', 'have', ';', 'is', 'an', 'hadn', 'haven', 'for', "weren't", 'ain', 'the', 'will', "couldn't", '&', "you've", 'those', 'both', '{', 'after', '/', "you'll", 'does', 'so', "she's", 'her', 'shouldn', 'd', 'in', 'once', '%', 'some', "needn't", '-', 'herself', 'they', 'y', 'myself', 'weren', 'over', 'mustn', 'ours', 'between', 'of', '"', 'more', '@', 'that', 'our', 'you', 'below', 'aren', "that'll", 'your', 'needn', "wouldn't", 'won', 'what', 'same', '!', 'again', 'm', 'up', 'out', ']', 'where', 've', 'off', 'do', 'there', 'he', 'me', 'be', '?', 'at', 'other', 'to', 'was', "'", "haven't", 'who', '}', 'i', 'then', 'as', 'any', "aren't", 'own', 'it', 'very', '+', '_', 'but', 'under', "shan't", 'wasn', "you'd", 'until', 'couldn', '$', 'which', "won't", 'o', 'from', 'further', '^', 'had', 'doesn', '`', 'with', 't', '#', 'wouldn', 'his', 'ma', ')', 'and', 'its', 'few', '.', '*', ':', 'him', 'on', '\\', 'during'
# ...

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_stopwords(text, is_lower_case=False):
    if is_lower_case:
        text = text.lower()
    tokens = nltk.word_tokenize(text)
    print("tokens:", tokens)
    tokens = [token.strip() for token in tokens] # remove blank
    print("striped tokens:", tokens)
    filtered_tokens = [token for token in tokens if token not in eng_stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text, filtered_tokens

# %%
# 測試文章段落
with open('./NLP_data/news.txt','r+', encoding='UTF-8') as f:
    text = f.read()

filtered_text, filtered_tokens = remove_stopwords(text, True) 

import collections
# word collection
word_freqs = collections.Counter()
for word in filtered_tokens:
    word_freqs[word] += 1
print(word_freqs.most_common(20))
# Out:
# tokens: ['president', 'biden', 'is', 'faced', 'with', 'the', 'thorny', 'reality', 'that', 'american', 'citizens', 'are', 'among', 'the', 'hostages', 'hamas', 'terrorists', 'kidnapped', 'and', 'took', 'into', 'gaza', 'over', 'the', 'weekend', ',', 'but', 'the', 'u.s.', 'government', 'doesn', '’', 't', 'know', 'exactly', 'how', 'many', 'of', 'its', 'citizens', 'are', 'in', 'that', 'situation', 'or', 'where', 'they', 'are', '.', '``', 'we', 'now', 'know', 'that', 'american', 'citizens', 'are', 'among', 'those', 'being', 'held', 'by', 'hamas', ',', "''", 'biden', 'told', 'reporters', 'in', 'the', 'white', 'house', 'state', 'dining', 'room', 'on', 'tuesday', '.', 'he', 'said', 'the', 'u.s.', 'military', 'would', 'be', 'helping', 'israeli', 'forces', 'in', 'the', 'planning', 'and', 'intelligence', 'collection', 'for', 'efforts', 'to', 'rescue', 'hostages', 'and', 'that', 'he', 'had', '“', 'no', 'higher', 'priority', '”', 'as', 'president', 'than', 'the', 'safety', 'of', 'americans', 'held'
# ...

# %%
filtered_text
# Out:
# "president biden faced thorny reality american citizens among hostages hamas terrorists kidnapped took gaza weekend u.s. government ’ know exactly many citizens situation `` know american citizens among held hamas '' biden told reporters white house state dining room tuesday said u.s. military would helping israeli forces planning intelligence collection efforts rescue hostages “ higher priority ” president safety americans held hostage around world speaking forcefully front portrait abraham lincoln biden called hamas ’ rampage towns farms southern israel slaughter 1,000 israelis “ pure unadulterated evil ” confirmed killed include 14 americans “ moment must crystal clear ” biden said “ stand israel '' beyond confirming hostages us citizens white house officials details options rescue available biden “ know condition confirm precise number american hostages ” national security advisor jake sullivan told reporters white house 20 american citizens israel missing sullivan said unclear m
# ...

# %%
filtered_tokens
# Out:
# ['president',
#  'biden',
#  'faced',
#  'thorny',
#  'reality',
#  'american',
#  'citizens',
#  'among',
#  'hostages',
#  'hamas',
#  'terrorists',
#  'kidnapped',
#  'took',
#  'gaza',
#  'weekend',
#  'u.s.',
#  'government',
#  '’',
#  'know',
#  'exactly',
#  'many',
#  'citizens',
#  'situation',
#  '``',
#  'know',
#  'american',
#  'citizens',
#  'among',
#  'held',
#  'hamas',
#  "''",
#  'biden',
#  'told',
#  'reporters',
#  'white',
#  'house',
#  'state',
#  'dining',
#  'room',
#  'tuesday',
#  'said',
#  'u.s.',
#  'military',
#  'would',
#  'helping',
#  'israeli',
#  'forces',
#  'planning',
#  'intelligence',
#  'collection',
#  'efforts',
#  'rescue',
#  'hostages',
#  '“',
#  'higher',
#  'priority',
#  '”',
#  'president',
#  'safety',
#  'americans',
#  'held',
#  'hostage',
#  'around',
#  'world',
#  'speaking',
#  'forcefully',
#  'front',
#  'portrait',
#  'abraham',
#  'lincoln',
#  'biden',
#  'called',
#  'hamas',
#  '’',
#  'rampage',
#  'towns',
# ...

# %%
def remove_stopwords(text, is_lower_case=False):
    if is_lower_case:
        text = text.lower()
    lem = nltk.WordNetLemmatizer()
    text = ' '.join([lem.lemmatize(word) for word in text.split()])
    tokens = nltk.word_tokenize(text)
    tokens = [token.strip() for token in tokens] # remove blank
    filtered_tokens = [token for token in tokens if token not in eng_stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text, filtered_tokens

# 測試文章段落
with open('./NLP_data/news.txt','r+', encoding='UTF-8') as f:
    text = f.read()

filtered_text, filtered_tokens = remove_stopwords(text, True) 

import collections
# word collection
word_freqs = collections.Counter()
for word in filtered_tokens:
    word_freqs[word] += 1
print(word_freqs.most_common(20))
# Out:
# [('u.s.', 12), ('israeli', 10), ('american', 9), ('hostage', 9), ('biden', 8), ('“', 8), ('hamas', 7), ('”', 7), ('citizen', 6), ('gaza', 6), ('said', 6), ('’', 5), ('know', 5), ('held', 5), ('rescue', 5), ('israel', 5), ('u', 5), ('neta', 5), ('wa', 4), ('family', 4)]

# %% [markdown]
# - 改用正規表達式(Regular Expression)去除標點符號

# %%
# 移除停用詞(Removing Stopwords)
lem = nltk.WordNetLemmatizer()
def remove_stopwords_regex(text, is_lower_case=False):
    if is_lower_case:
        text = text.lower()
    # 原先使用 nltk.word_tokenize(text) 仍有標點符號
    tokenizer = nltk.tokenize.RegexpTokenizer(r'\w+') # 篩選文數字(Alphanumeric)
    tokens = tokenizer.tokenize(text)
    print("tokens_1:", tokens)
    tokens = [lem.lemmatize(token.strip()) for token in tokens] # 詞形還原
    print("tokens_2:", tokens)
    filtered_tokens = [token for token in tokens if token not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text, filtered_tokens

filtered_text, filtered_tokens = remove_stopwords_regex(text, True) 
word_freqs = collections.Counter()
for word in filtered_tokens:
    word_freqs[word] += 1
print(word_freqs.most_common(20))
# Out:
# tokens_1: ['president', 'biden', 'is', 'faced', 'with', 'the', 'thorny', 'reality', 'that', 'american', 'citizens', 'are', 'among', 'the', 'hostages', 'hamas', 'terrorists', 'kidnapped', 'and', 'took', 'into', 'gaza', 'over', 'the', 'weekend', 'but', 'the', 'u', 's', 'government', 'doesn', 't', 'know', 'exactly', 'how', 'many', 'of', 'its', 'citizens', 'are', 'in', 'that', 'situation', 'or', 'where', 'they', 'are', 'we', 'now', 'know', 'that', 'american', 'citizens', 'are', 'among', 'those', 'being', 'held', 'by', 'hamas', 'biden', 'told', 'reporters', 'in', 'the', 'white', 'house', 'state', 'dining', 'room', 'on', 'tuesday', 'he', 'said', 'the', 'u', 's', 'military', 'would', 'be', 'helping', 'israeli', 'forces', 'in', 'the', 'planning', 'and', 'intelligence', 'collection', 'for', 'efforts', 'to', 'rescue', 'hostages', 'and', 'that', 'he', 'had', 'no', 'higher', 'priority', 'as', 'president', 'than', 'the', 'safety', 'of', 'americans', 'held', 'hostage', 'around', 'the', 'world', 's
# ...

# %% [markdown]
# # 相似詞(Synonyms)

# %%
synonyms = nltk.corpus.wordnet.synsets('love')
synonyms
# Out:
# [Synset('love.n.01'),
#  Synset('love.n.02'),
#  Synset('beloved.n.01'),
#  Synset('love.n.04'),
#  Synset('love.n.05'),
#  Synset('sexual_love.n.02'),
#  Synset('love.v.01'),
#  Synset('love.v.02'),
#  Synset('love.v.03'),
#  Synset('sleep_together.v.01')]

# %%
# word expain
synonyms[0].definition()
# Out:
# 'a strong positive emotion of regard and affection'

# %% [markdown]
# # 相反詞(Antonyms)

# %%
antonyms=[]
for syn in nltk.corpus.wordnet.synsets('ugly'):
    print(type(syn))
    # lemmas: 詞形還原
    for l in syn.lemmas():
        print(type(l))
        print(l)
        if l.antonyms():
            print(l.antonyms())
            antonyms.append(l.antonyms()[0].name())
antonyms
# Out:
# <class 'nltk.corpus.reader.wordnet.Synset'>
# <class 'nltk.corpus.reader.wordnet.Lemma'>
# Lemma('ugly.a.01.ugly')
# [Lemma('beautiful.a.01.beautiful')]
# <class 'nltk.corpus.reader.wordnet.Synset'>
# <class 'nltk.corpus.reader.wordnet.Lemma'>
# Lemma('surly.s.01.surly')
# <class 'nltk.corpus.reader.wordnet.Lemma'>
# Lemma('surly.s.01.ugly')
# <class 'nltk.corpus.reader.wordnet.Synset'>
# <class 'nltk.corpus.reader.wordnet.Lemma'>
# Lemma('despicable.s.01.despicable')
# <class 'nltk.corpus.reader.wordnet.Lemma'>
# Lemma('despicable.s.01.ugly')
# <class 'nltk.corpus.reader.wordnet.Lemma'>
# Lemma('despicable.s.01.vile')
# <class 'nltk.corpus.reader.wordnet.Lemma'>
# Lemma('despicable.s.01.slimy')
# <class 'nltk.corpus.reader.wordnet.Lemma'>
# Lemma('despicable.s.01.unworthy')
# <class 'nltk.corpus.reader.wordnet.Lemma'>
# Lemma('despicable.s.01.worthless')
# <class 'nltk.corpus.reader.wordnet.Lemma'>
# Lemma('despicable.s.01.wretched')
# <class 'nltk.corpus.reader.wordnet.Synset'>
# ...

# %% [markdown]
# # 詞性標籤(POS Tagging)

# %%
# 找出詞性標籤(POS Tagging)
text='I am a human being, capable of doing terrible things'
sentences=nltk.sent_tokenize(text)
for sent in sentences:
    print(nltk.pos_tag(nltk.word_tokenize(sent)))
# Out:
# [('I', 'PRP'), ('am', 'VBP'), ('a', 'DT'), ('human', 'JJ'), ('being', 'VBG'), (',', ','), ('capable', 'JJ'), ('of', 'IN'), ('doing', 'VBG'), ('terrible', 'JJ'), ('things', 'NNS')]
